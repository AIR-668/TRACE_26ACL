# %% [markdown]
# # Step 1：设置环境变量（正确方式）

# %%
import os
os.environ["OPENAI_API_KEY"] = "" # 你的key
os.environ["OPENAI_API_MODEL"] = "gpt-4o"   # 统一模型，方便测试
os.environ["CUDA_VISIBLE_DEVICES"] = "0"    # 如果需要

os.chdir("/workspace")
print(os.getcwd())
# Out:
# /workspace

# %%
# 检查
os.environ["OPENAI_API_KEY"][:8]
# Out:
# 'sk-proj-'

# %% [markdown]
# # Step 2：运行 translate_decompose

# %%
# !python /workspace/translate_decompose.py \
    --api_key "$OPENAI_API_KEY" \
    --model_name "gpt-4o" \
    --data_path "/workspace/data" \
    --dataset_name "LogicNLI" \
    --split dev \
    --max_new_tokens 2048 \
    --batch_num 1
# Out:
# Loaded 300 examples from dev split.
# Loading translation file:  ./prompts/LogicNLI/translation.txt
# Loading decomposer file:  ./prompts/LogicNLI/and_or_decomposer.txt
# Loading decomposer file:  ./prompts/LogicNLI/either_or_decomposer.txt
# Loading decomposer file:  ./prompts/LogicNLI/logical_biconditional_decomposer.txt
# Number of batch:  1
# Translating...
#   0%|                                                   | 0/300 [00:00<?, ?it/s]Translation response:  To translate the given context and conjecture into logical form, we will follow the steps outlined in the task description.
#
# ### Final Translation:
#
# **Facts:**
# 1. Eager(Vivian, True) ::: Vivian is eager.
# 2. Modest(Rhett, False) ::: Rhett is not modest.
# 3. Confused(Vivian, True) ::: Vivian is confused.
# 4. Lazy(Vivian, False) ::: Vivian is not lazy.
# 5. Eager(Atwater, True) ::: Atwater is eager.
# 6. Confused(Philip, False) ::: Philip is not confused.
# 7. Eager(Giles, False) ::: Giles is not eager.
# ...
